# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# # Perform API Calls
#
# #Perform a weather check on each city using a series of successive API calls.
#
# #Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set url and units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

#Define URL Query 
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# Initialize list to store data from retrival
city_id = []
city_list = []
country = []
date = []
lat_list = []
lng_list = []
max_temp = []
wind = []
humidity = []
cloudiness = []

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

city_counter = 0
set_counter = 1

#loop thorugh the cities and append results to lists
for city in cities:

    response = requests.get(query_url + city).json() 

    try:
        city_id.append(response['id'])
        city_list.append(response['name'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        lat_list.append(response['coord']['lat'])
        lng_list.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max']) 
        wind.append(response['wind']['speed'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
            
  
        if city_counter >= 49:
            city_counter = 0
            set_counter += 1
        else:
            city_counter +=1

        print(f"Processing Record {city_counter} of Set {set_counter} | {city}")
   
    #print except message and skip
    except (KeyError, IndexError):
        print(f"City {city} not found. Skipping...")
  
    

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | lyuban
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | kahului
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | unecha
# Processing Record 9 of Set 1 | samarai
# Processing Record 10 of Set 1 | stepnyak
# Processing Record 11 of Set 1 | rawson
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | nikolskoye
# City tabialan not found. Skipping...
# Processing Record 15 of Set 1 | broome
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | lavrentiya
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | hilo
# City barentsburg not found. Skipping...
# Processing Record 25 of Set 1 | geraldton
# Processing Record 26 of Set 1 | saint-philippe
# City guelengdeng not found. Skipping...
# Processing Record 27 of Set 1 | bowen
# Processing Record 28 of Set 1 | sabha
# Processing Record 29 of Set 1 | kalangala
# Processing Record 30 of Set 1 | kamenskiy
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | funtua
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | gigmoto
# Processing Record 36 of Set 1 | hofn
# Processing Record 37 of Set 1 | bengkulu
# Processing Record 38 of Set 1 | tuatapere
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | maningrida
# Processing Record 42 of Set 1 | bethel
# City amderma not found. Skipping...
# City vaitupu not found. Skipping...
# Processing Record 43 of Set 1 | zaysan
# Processing Record 44 of Set 1 | padang
# Processing Record 45 of Set 1 | ihosy
# Processing Record 46 of Set 1 | key west
# Processing Record 47 of Set 1 | hovd
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 0 of Set 2 | mount gambier
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | banatski karlovac
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | kurilsk
# Processing Record 5 of Set 2 | aragats
# Processing Record 6 of Set 2 | ahipara
# Processing Record 7 of Set 2 | norman wells
# Processing Record 8 of Set 2 | laguna
# Processing Record 9 of Set 2 | los llanos de aridane
# Processing Record 10 of Set 2 | port blair
# Processing Record 11 of Set 2 | vardo
# Processing Record 12 of Set 2 | terney
# City nizhneyansk not found. Skipping...
# Processing Record 13 of Set 2 | sheridan
# City attawapiskat not found. Skipping...
# City taolanaro not found. Skipping...
# Processing Record 14 of Set 2 | nome
# Processing Record 15 of Set 2 | arlit
# Processing Record 16 of Set 2 | kruisfontein
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | jinchang
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | dalvik
# Processing Record 21 of Set 2 | bilma
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | velez-malaga
# City temaraia not found. Skipping...
# Processing Record 24 of Set 2 | panguna
# Processing Record 25 of Set 2 | souillac
# City banmo not found. Skipping...
# City samalaeulu not found. Skipping...
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | igarka
# Processing Record 0 of Set 4 | sumbe
# Processing Record 1 of Set 4 | rovaniemi
# Processing Record 2 of Set 4 | aklavik
# Processing Record 3 of Set 4 | alice springs
# Processing Record 4 of Set 4 | marondera
# Processing Record 5 of Set 4 | cooma
# Processing Record 6 of Set 4 | hasaki
# City malwan not found. Skipping...
# Processing Record 7 of Set 4 | hamilton
# Processing Record 8 of Set 4 | port alfred
# Processing Record 9 of Set 4 | deputatskiy
# Processing Record 10 of Set 4 | manta
# Processing Record 11 of Set 4 | gat
# City kuche not found. Skipping...
# Processing Record 12 of Set 4 | rio grande
# Processing Record 13 of Set 4 | pisco
# Processing Record 14 of Set 4 | abbeville
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | aguimes
# Processing Record 17 of Set 4 | viisoara
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | canutama
# Processing Record 20 of Set 4 | hermanus
# Processing Record 21 of Set 4 | katsuura
# Processing Record 22 of Set 4 | kidal
# Processing Record 23 of Set 4 | bredasdorp
# Processing Record 24 of Set 4 | upernavik
# Processing Record 25 of Set 4 | kemijarvi
# Processing Record 26 of Set 4 | provideniya
# Processing Record 27 of Set 4 | georgetown
# Processing Record 28 of Set 4 | mehamn
# Processing Record 29 of Set 4 | san cristobal
# Processing Record 30 of Set 4 | emerald
# Processing Record 31 of Set 4 | oistins
# City saleaula not found. Skipping...
# Processing Record 32 of Set 4 | thiruvananthapuram
# City ambodifototra not found. Skipping...
# Processing Record 33 of Set 4 | bima
# Processing Record 34 of Set 4 | grants
# Processing Record 35 of Set 4 | grand gaube
# Processing Record 36 of Set 4 | ilulissat
# Processing Record 37 of Set 4 | ketchikan
# Processing Record 38 of Set 4 | kaitangata
# Processing Record 39 of Set 4 | general roca
# Processing Record 40 of Set 4 | huarmey
# Processing Record 41 of Set 4 | ponta delgada
# Processing Record 42 of Set 4 | prachuap khiri khan
# Processing Record 43 of Set 4 | tobol
# Processing Record 44 of Set 4 | faanui
# Processing Record 45 of Set 4 | cozumel
# Processing Record 46 of Set 4 | mpika
# Processing Record 47 of Set 4 | vila
# Processing Record 48 of Set 4 | ancud
# Processing Record 49 of Set 4 | thessalon
# Processing Record 0 of Set 5 | ankazoabo
# Processing Record 1 of Set 5 | bayir
# City mocambique not found. Skipping...
# Processing Record 2 of Set 5 | kununurra
# Processing Record 3 of Set 5 | buhovo
# Processing Record 4 of Set 5 | moranbah
# Processing Record 5 of Set 5 | namatanai
# Processing Record 6 of Set 5 | bam
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | moanda
# Processing Record 9 of Set 5 | clyde river
# Processing Record 10 of Set 5 | ocampo
# Processing Record 11 of Set 5 | katangli
# Processing Record 12 of Set 5 | kaka
# Processing Record 13 of Set 5 | kaeo
# Processing Record 14 of Set 5 | rafaela
# Processing Record 15 of Set 5 | solnechnyy
# Processing Record 16 of Set 5 | pokhara
# Processing Record 17 of Set 5 | husavik
# Processing Record 18 of Set 5 | porto novo
# Processing Record 19 of Set 5 | listvyagi
# Processing Record 20 of Set 5 | abnub
# Processing Record 21 of Set 5 | khatanga
# Processing Record 22 of Set 5 | port-gentil
# Processing Record 23 of Set 5 | yar-sale
# Processing Record 24 of Set 5 | labuan
# Processing Record 25 of Set 5 | sisimiut
# Processing Record 26 of Set 5 | plettenberg bay
# Processing Record 27 of Set 5 | dicabisagan
# Processing Record 28 of Set 5 | negri
# Processing Record 29 of Set 5 | kavieng
# Processing Record 30 of Set 5 | vila franca do campo
# Processing Record 31 of Set 5 | clovis
# City sentyabrskiy not found. Skipping...
# Processing Record 32 of Set 5 | lensk
# City belushya guba not found. Skipping...
# Processing Record 33 of Set 5 | tabou
# Processing Record 34 of Set 5 | almeirim
# Processing Record 35 of Set 5 | saint-augustin
# Processing Record 36 of Set 5 | naze
# Processing Record 37 of Set 5 | weatherford
# Processing Record 38 of Set 5 | khonsa
# Processing Record 39 of Set 5 | matamoros
# City bargal not found. Skipping...
# Processing Record 40 of Set 5 | port elizabeth
# City tsihombe not found. Skipping...
# Processing Record 41 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 5 | kasane
# Processing Record 43 of Set 5 | petropavl
# Processing Record 44 of Set 5 | tasiilaq
# Processing Record 45 of Set 5 | charters towers
# Processing Record 46 of Set 5 | bonavista
# Processing Record 47 of Set 5 | gazanjyk
# Processing Record 48 of Set 5 | baishishan
# Processing Record 49 of Set 5 | atasu
# Processing Record 0 of Set 6 | sangar
# Processing Record 1 of Set 6 | kamskiye polyany
# Processing Record 2 of Set 6 | bay roberts
# Processing Record 3 of Set 6 | springbok
# Processing Record 4 of Set 6 | iquique
# Processing Record 5 of Set 6 | dunedin
# Processing Record 6 of Set 6 | santa isabel
# Processing Record 7 of Set 6 | aykhal
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | aitape
# Processing Record 10 of Set 6 | hambantota
# Processing Record 11 of Set 6 | presidente olegario
# Processing Record 12 of Set 6 | kuzhenkino
# Processing Record 13 of Set 6 | vrangel
# Processing Record 14 of Set 6 | kodiak
# Processing Record 15 of Set 6 | isla mujeres
# Processing Record 16 of Set 6 | saldanha
# Processing Record 17 of Set 6 | weinan
# Processing Record 18 of Set 6 | alexandria
# City palabuhanratu not found. Skipping...
# Processing Record 19 of Set 6 | ulladulla
# Processing Record 20 of Set 6 | okhotsk
# Processing Record 21 of Set 6 | high level
# City tawkar not found. Skipping...
# Processing Record 22 of Set 6 | nago
# Processing Record 23 of Set 6 | mtambile
# Processing Record 24 of Set 6 | matagami
# Processing Record 25 of Set 6 | surt
# Processing Record 26 of Set 6 | kyaukse
# Processing Record 27 of Set 6 | pontianak
# Processing Record 28 of Set 6 | isangel
# Processing Record 29 of Set 6 | maxineni
# Processing Record 30 of Set 6 | camopi
# Processing Record 31 of Set 6 | balikpapan
# Processing Record 32 of Set 6 | zhicheng
# Processing Record 33 of Set 6 | barranca
# Processing Record 34 of Set 6 | nioro
# Processing Record 35 of Set 6 | port moresby
# Processing Record 36 of Set 6 | college
# Processing Record 37 of Set 6 | dauphin
# Processing Record 38 of Set 6 | shizunai
# Processing Record 39 of Set 6 | paamiut
# Processing Record 40 of Set 6 | touros
# Processing Record 41 of Set 6 | esperance
# Processing Record 42 of Set 6 | bubaque
# Processing Record 43 of Set 6 | coos bay
# Processing Record 44 of Set 6 | svetlyy
# Processing Record 45 of Set 6 | mandurah
# Processing Record 46 of Set 6 | axim
# Processing Record 47 of Set 6 | isiro
# Processing Record 48 of Set 6 | mayo
# Processing Record 49 of Set 6 | saint-francois
# Processing Record 0 of Set 7 | inuvik
# City unye not found. Skipping...
# City grand centre not found. Skipping...
# Processing Record 1 of Set 7 | shingu
# Processing Record 2 of Set 7 | maceio
# Processing Record 3 of Set 7 | parangan
# Processing Record 4 of Set 7 | sao felix do xingu
# Processing Record 5 of Set 7 | bairiki
# Processing Record 6 of Set 7 | tual
# Processing Record 7 of Set 7 | praia da vitoria
# Processing Record 8 of Set 7 | bilibino
# Processing Record 9 of Set 7 | saint-pierre
# Processing Record 10 of Set 7 | birao
# Processing Record 11 of Set 7 | san quintin
# Processing Record 12 of Set 7 | kutum
# Processing Record 13 of Set 7 | beloha
# Processing Record 14 of Set 7 | sikasso
# Processing Record 15 of Set 7 | kyela
# Processing Record 16 of Set 7 | taitung
# Processing Record 17 of Set 7 | aleysk
# Processing Record 18 of Set 7 | chilliwack
# Processing Record 19 of Set 7 | grand-santi
# Processing Record 20 of Set 7 | sinnamary
# City karaul not found. Skipping...
# Processing Record 21 of Set 7 | oxapampa
# Processing Record 22 of Set 7 | eskisehir
# Processing Record 23 of Set 7 | cravo norte
# Processing Record 24 of Set 7 | zhezkazgan
# City samusu not found. Skipping...
# Processing Record 25 of Set 7 | southampton
# Processing Record 26 of Set 7 | fukue
# Processing Record 27 of Set 7 | horsham
# Processing Record 28 of Set 7 | suntar
# Processing Record 29 of Set 7 | berezovyy
# Processing Record 30 of Set 7 | ayr
# Processing Record 31 of Set 7 | acari
# Processing Record 32 of Set 7 | benghazi
# Processing Record 33 of Set 7 | lebu
# Processing Record 34 of Set 7 | salym
# Processing Record 35 of Set 7 | poum
# Processing Record 36 of Set 7 | thinadhoo
# Processing Record 37 of Set 7 | abu dhabi
# Processing Record 38 of Set 7 | mantua
# Processing Record 39 of Set 7 | flinders
# Processing Record 40 of Set 7 | cidreira
# Processing Record 41 of Set 7 | hualmay
# Processing Record 42 of Set 7 | baker city
# Processing Record 43 of Set 7 | jurado
# Processing Record 44 of Set 7 | izberbash
# City mutsamudu not found. Skipping...
# Processing Record 45 of Set 7 | namibe
# Processing Record 46 of Set 7 | sibu
# Processing Record 47 of Set 7 | te anau
# Processing Record 48 of Set 7 | pengcheng
# City viligili not found. Skipping...
# Processing Record 49 of Set 7 | zyryanka
# City rolim de moura not found. Skipping...
# Processing Record 19 of Set 9 | rosetta
# Processing Record 20 of Set 9 | virginia beach
# Processing Record 21 of Set 9 | lar
# City jabiru not found. Skipping...
# Processing Record 22 of Set 9 | batagay
# Processing Record 23 of Set 9 | richards bay
# Processing Record 24 of Set 9 | swan river
# Processing Record 25 of Set 9 | williston
# Processing Record 26 of Set 9 | eenhana
# Processing Record 27 of Set 9 | omboue
# Processing Record 28 of Set 9 | bagdarin
# City karkaralinsk not found. Skipping...
# Processing Record 29 of Set 9 | dingle
# Processing Record 30 of Set 9 | cavalcante
# Processing Record 31 of Set 9 | fort morgan
# Processing Record 32 of Set 9 | port hawkesbury
# Processing Record 33 of Set 9 | gornopravdinsk
# Processing Record 34 of Set 9 | santana
# Processing Record 35 of Set 9 | poronaysk
# Processing Record 36 of Set 9 | zhangye
# Processing Record 37 of Set 9 | barao de melgaco
# Processing Record 38 of Set 9 | adrar
# Processing Record 39 of Set 9 | vao
# Processing Record 40 of Set 9 | nhulunbuy
# City bolshoy tsaryn not found. Skipping...
# Processing Record 41 of Set 9 | plover
# Processing Record 42 of Set 9 | cabral
# Processing Record 43 of Set 9 | ziro
# Processing Record 44 of Set 9 | kalengwa
# Processing Record 45 of Set 9 | great yarmouth
# Processing Record 46 of Set 9 | turukhansk
# Processing Record 47 of Set 9 | presidencia roque saenz pena
# Processing Record 48 of Set 9 | sitka
# Processing Record 49 of Set 9 | krasnoselkup
# Processing Record 0 of Set 10 | wellington
# Processing Record 1 of Set 10 | saint-georges
# Processing Record 2 of Set 10 | jati
# Processing Record 3 of Set 10 | shache
# Processing Record 4 of Set 10 | batagay-alyta
# Processing Record 5 of Set 10 | lasa
# Processing Record 6 of Set 10 | vallenar
# Processing Record 7 of Set 10 | krasnokamensk
# Processing Record 8 of Set 10 | baruun-urt
# Processing Record 9 of Set 10 | ginir
# Processing Record 10 of Set 10 | marsaxlokk
# Processing Record 11 of Set 10 | beira
# Processing Record 12 of Set 10 | nisia floresta
# Processing Record 13 of Set 10 | murfreesboro
# Processing Record 14 of Set 10 | sorland
# Processing Record 15 of Set 10 | yining
# Processing Record 16 of Set 10 | tomatlan
# Processing Record 17 of Set 10 | bay city
# Processing Record 18 of Set 10 | klaksvik
# Processing Record 19 of Set 10 | maracacume
# Processing Record 20 of Set 10 | eureka
# Processing Record 21 of Set 10 | moyale
# Processing Record 22 of Set 10 | chihuahua
# Processing Record 23 of Set 10 | sorong
# Processing Record 24 of Set 10 | constitucion
# Processing Record 25 of Set 10 | schmallenberg
# Processing Record 26 of Set 10 | storforshei
# Processing Record 27 of Set 10 | jagtial
# Processing Record 28 of Set 10 | chiredzi
# Processing Record 29 of Set 10 | sandy bay
# City svistov not found. Skipping...
# Processing Record 30 of Set 10 | paita
# Processing Record 31 of Set 10 | tongchuan
# Processing Record 32 of Set 10 | berlevag
# Processing Record 33 of Set 10 | meadow lake
# Processing Record 34 of Set 10 | nuuk
# Processing Record 35 of Set 10 | makokou
# Processing Record 36 of Set 10 | alugan
# Processing Record 37 of Set 10 | lindas
# Processing Record 38 of Set 10 | tocopilla
# Processing Record 39 of Set 10 | muzhi
# Processing Record 40 of Set 10 | brae
# Processing Record 41 of Set 10 | sakakah
# Processing Record 42 of Set 10 | betul
# Processing Record 43 of Set 10 | livani
# Processing Record 44 of Set 10 | kudahuvadhoo
# Processing Record 45 of Set 10 | fairbanks
# Processing Record 46 of Set 10 | esmeraldas
# Processing Record 47 of Set 10 | colares
# Processing Record 48 of Set 10 | portales
# Processing Record 49 of Set 10 | camacha
# Processing Record 0 of Set 11 | codrington
# Processing Record 1 of Set 11 | tamandare
# Processing Record 2 of Set 11 | sokolo
# Processing Record 3 of Set 11 | faya
# Processing Record 4 of Set 11 | ust-kuyga
# Processing Record 5 of Set 11 | mogadishu
# Processing Record 6 of Set 11 | harij
# Processing Record 7 of Set 11 | leningradskiy
# Processing Record 8 of Set 11 | martapura
# Processing Record 9 of Set 11 | isabela
# Processing Record 10 of Set 11 | ambovombe
# Processing Record 11 of Set 11 | maniitsoq
# Processing Record 12 of Set 11 | denpasar
# Processing Record 13 of Set 11 | maragogi
# Processing Record 14 of Set 11 | osypenko
# Processing Record 15 of Set 11 | el alto
# Processing Record 16 of Set 11 | plouzane
# Processing Record 17 of Set 11 | broken hill
# Processing Record 18 of Set 11 | baiao
# Processing Record 19 of Set 11 | carutapera
# Processing Record 20 of Set 11 | pacific grove
# Processing Record 21 of Set 11 | bratsk
# Processing Record 22 of Set 11 | ocean city
# Processing Record 23 of Set 11 | odienne
# Processing Record 24 of Set 11 | brooks
# Processing Record 25 of Set 11 | bat khela
# Processing Record 26 of Set 11 | moctezuma
# Processing Record 27 of Set 11 | saint-louis
# Processing Record 28 of Set 11 | kamina
# Processing Record 29 of Set 11 | narsaq
# City umzimvubu not found. Skipping...
# Processing Record 30 of Set 11 | santa lucia
# Processing Record 31 of Set 11 | trincomalee
# Processing Record 32 of Set 11 | mamou
# City kamenskoye not found. Skipping...
# City muzquiz not found. Skipping...
# Processing Record 33 of Set 11 | mount isa
# Processing Record 34 of Set 11 | ilabaya
# Processing Record 35 of Set 11 | tafresh
# City masjed-e soleyman not found. Skipping...
# Processing Record 36 of Set 11 | jalu
# Processing Record 37 of Set 11 | katherine
# Processing Record 38 of Set 11 | basco
# Processing Record 39 of Set 11 | palmerston
# Processing Record 40 of Set 11 | tadine
# City rungata not found. Skipping...
# Processing Record 41 of Set 11 | changping
# Processing Record 42 of Set 11 | belmonte
# Processing Record 43 of Set 11 | grootfontein
# Processing Record 44 of Set 11 | fayaoue
# City mrirt not found. Skipping...
# Processing Record 45 of Set 11 | port lincoln
# City bur gabo not found. Skipping...
# Processing Record 46 of Set 11 | esso
# Processing Record 47 of Set 11 | bauchi
# Processing Record 48 of Set 11 | ndele
# Processing Record 49 of Set 11 | bodmin
# Processing Record 0 of Set 12 | ayan
# Processing Record 1 of Set 12 | turceni
# Processing Record 2 of Set 12 | avanigadda
# City khonsar not found. Skipping...
# Processing Record 3 of Set 12 | yarada
# Processing Record 4 of Set 12 | fiumicino
# Processing Record 5 of Set 12 | petrovsk-zabaykalskiy
# Processing Record 6 of Set 12 | knysna
# Processing Record 7 of Set 12 | neiafu
# Processing Record 8 of Set 12 | guane
# Processing Record 9 of Set 12 | tura
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_list)
# Out:
# 559

# %%
#Convert to dataFrame
weather_df = pd.DataFrame({
    "ID" : city_id,
    "City" : city_list,
    "Lat" : lat_list,
    "Lng" : lng_list,
    "Max Temp" : max_temp,
    "Humidity" : humidity,
    "Cloudiness" : cloudiness,
    "Wind Speed" : wind,
    "Country" : country,
    "Date" : date})
weather_df.head()
# Out:
#         ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  2110227  Butaritari   3.0707  172.7902     28.04        76          93
# 1  4030556     Rikitea -23.1203 -134.9692     24.85        74         100
# 2   625721     Lyuban'  52.7985   28.0048      2.97        83         100
# 3  5983720     Iqaluit  63.7506  -68.5145     -9.00        92          20
# 4  4020109      Atuona  -9.8000 -139.0333     26.65        74          24
#
#    Wind Speed Country        Date
# 0        3.64      KI  1619581972
# 1        5.21      PF  1619581761
# 2        2.26      BY  1619581972
# 3        1.58      CA  1619581973
# 4        5.56      PF  1619582534

# %%
#Export dataframe to csv file
weather_df.to_csv("../output_data/cities.csv")

# %%
#display statistics for the dataframe
weather_df.describe()
# Out:
#                  ID         Lat         Lng    Max Temp    Humidity  \
# count  5.590000e+02  559.000000  559.000000  559.000000  559.000000
# mean   2.643049e+06   19.958633   20.564256   16.251968   69.983900
# std    1.610134e+06   33.269406   90.153922   10.622530   23.398176
# min    5.365400e+04  -54.800000 -175.200000  -10.000000    5.000000
# 25%    1.506829e+06   -8.362250  -55.473300    8.000000   57.000000
# 50%    2.180815e+06   24.555700   23.616000   18.000000   76.000000
# 75%    3.528430e+06   47.748950  100.042700   24.695000   88.000000
# max    7.601762e+06   78.218600  179.316700   38.630000  100.000000
#
#        Cloudiness  Wind Speed          Date
# count  559.000000  559.000000  5.590000e+02
# mean    55.525939    3.294079  1.619582e+09
# std     37.804567    2.191508  9.112994e+01
# min      0.000000    0.150000  1.619582e+09
# 25%     20.000000    1.540000  1.619582e+09
# 50%     67.000000    2.790000  1.619582e+09
# 75%     90.500000    4.490000  1.619582e+09
# max    100.000000   11.650000  1.619582e+09

# %%
#Inspect the data and remove the cities where the humidity > 100%.

#Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Plot variables from dataframe
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o")

#labels
plt.title("City Latitude vs. Max Temperature (04/27/21)")
plt.ylabel("Max. Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save and show plot
plt.savefig("../output_data/latitude_vs_maxtemp.png")
plt.show()

# %%
# Plot variables from dataframe
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o")

#labels
plt.title("City Latitude vs. Humidity (04/27/21)")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save and show plot
plt.savefig("../output_data/latitude_vs_humidity.png")
plt.show()

# %%
# Plot variables from dataframe
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o")

#labels
plt.title("City Latitude vs. Wind Speed (04/27/21)")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save and show plot
plt.savefig("../output_data/latitude_vs_windspeed.png")
plt.show()
